# %% [markdown]
# # Hands on **Seaborn**
#
#
# I am going to learn "Data Visualization" by **Seaborn** from a hands-on **Kaggle** course through some real life datasets.
#
# ---
# ## 1 · Introduction
#
# **Seaborn** is a library for making statistical graphics in **Python**. It builds on top of **Matplotlib** and integrates closely with **Pandas** data structures. **Seaborn** can't draw a graph on its own.
#
# **Seaborn** is actually based on **Matplotlib**. So, It is good habit to import **Matplotlib** when using **Seaborn** . Since in this course I will learn by doing real life problem, I will import **Pandas** also.
#
# Lets do it ...

# %%
# notebook setup :
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# The following command called : Magic Commmand
# but this is not needed anymore now
#%matplotlib inline

# for registering timeseries data's time as Time in matplotlib :
pd.plotting.register_matplotlib_converters()

print('Setup Completed.')
# Out:
# Setup Completed.

# %% [markdown]
# ---
# Lets load our dataset to learn by doing...

# %%
# historical fifa rankings :
data = '/kaggle/input/datasets/alexisbcook/data-for-datavis/fifa.csv'

fifa = pd.read_csv(data, index_col='Date', parse_dates=True)

# %% [markdown]
# Lets describe our codes :
#
# - `index_col='Date'` - When we load the dataset, we want each entry in the first column to denote a different row.
# - `parse_dates=True` - This tells the notebook to understand the each row label as a date (as opposed to a number or other text with a different meaning).
#
# ---
# Lets check our Dataset :

# %%
# first 5 rows :
fifa.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
# renaming axis :
fifa.rename_axis(columns='Countries')
# Out:
# Countries    ARG  BRA   ESP   FRA  GER   ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ...          ...  ...   ...   ...  ...   ...
# 2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 6 columns]

# %% [markdown]
# ---
# ## 2 · Visualization
#
# Now I am going to make my first and simple visualization by **Seaborn**.

# %%
# simple visalization of fifa dataset :

# plt : figure making by plt :
plt.figure(figsize=(14, 5))

# line chart by sns ;
sns.lineplot(data=fifa)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ---
# I can quickly change the style of the figure to a different theme with only a single line of code.
#
# **Seaborn** has five different themes:
#
# 1. whitegrid
# 2. darkgrid
# 3. white
# 4. dark
# 5. ticks
#
# I can change theme anytime by running : `sns.set_style("dark")` .

# %%
# visualization with `tick` theme :
sns.set_style('darkgrid')

# plt : figure making by plt :
plt.figure(figsize=(14, 5))

# line chart by sns ;
sns.lineplot(data=fifa)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ---
# ## 3 · Line Graph
#
# **Line Graph** is a **chart** that is used to display quantitative values over a continuous interval or time period. A **Line Graph** is most frequently used to show trends and analyse how the data has changed over time.
#
# ---
# Lets make our first decorated **Line Graph** . . .

# %%
# simple decorated line graph of fifa rankings :
# chart's width and hight :
plt.figure(figsize=(14, 5))

# title for graph
plt.title('Historical FIFA Rankings')

# line graph by sns :
sns.lineplot(data=fifa)
# Out:
# <Axes: title={'center': 'Historical FIFA Rankings'}, xlabel='Date'>

# %% [markdown]
# ---
# What will I write to see line graph of 'ARG' and 'BRA' only ? Then I will write :

# %%
# line graph for Argentina and Brazil only :
plt.figure(figsize=(16, 5))

plt.title('Historical FIFA Rankings of Argentina and Brazil')

sns.lineplot(data=[fifa.ARG, fifa.BRA])
# Out:
# <Axes: title={'center': 'Historical FIFA Rankings of Argentina and Brazil'}, xlabel='Date'>

# %% [markdown]
# ---
# Or we can draw with `labels` :

# %%
# line graph for Argentina and Brazil only :
plt.figure(figsize=(16, 5))

plt.title('Historical FIFA Rankings of Argentina and Brazil')

sns.lineplot(data=fifa.ARG, label='Argentina')
sns.lineplot(data=fifa.BRA, label='Brazil')
# Out:
# <Axes: title={'center': 'Historical FIFA Rankings of Argentina and Brazil'}, xlabel='Date', ylabel='ARG'>

# %% [markdown]
# ---
# ## 4 · Bar Chart
#
# Now I will draw a **Bar Chart** by **Seaborn** with a dataset from the US Department of Transportation that tracks flight delays.

# %%
# loading the dataset :
file   = '/kaggle/input/datasets/alexisbcook/data-for-datavis/flight_delays.csv'
flight = pd.read_csv(file, index_col='Month')

flight.tail()
# Out:
#              AA        AS         B6        DL        EV         F9        HA  \
# Month
# 8      3.193907  2.503899   9.280950  0.653114  5.154422   9.175737  7.448029
# 9     -1.432732 -1.813800   3.539154 -3.703377  0.851062   0.978460  3.696915
# 10    -0.580930 -2.993617   3.676787 -5.011516  2.303760   0.082127  0.467074
# 11     0.772630 -1.916516   1.418299 -3.175414  4.415930  11.164527 -2.719894
# 12     4.149684 -1.846681  13.839290  2.504595  6.685176   9.346221 -1.706475
#
#              MQ         NK         OO        UA  US         VX        WN
# Month
# 8      1.896565  20.519018   5.606689  5.014041 NaN   5.106221  5.532108
# 9     -2.167268   8.000101   1.530896 -1.794265 NaN   0.070998 -1.336260
# 10    -3.735054   6.810736   1.750897 -2.456542 NaN   2.254278 -0.688851
# 11     0.220061   7.543881   4.925548  0.281064 NaN   0.116370  0.995684
# 12     0.662486  12.733123  10.947612  7.012079 NaN  13.498720  6.720893

# %%
# drawing bar chart :
plt.figure(figsize=(16, 6))
plt.title('Average Arrival Delay, by Month')

flight = flight.tail(10)

sns.barplot(x=flight.index, y=flight['NK'])

plt.xlabel('Month')
plt.ylabel('Arrival Delay (in minutes)')
plt.show()

# %% [markdown]
# It has three main components:
#
# - `sns.barplot` - This tells the notebook that we want to create a bar chart.
# - `x=flight.index` - This determines what to use on the horizontal axis.
# - `y=flight_data['NK']` - This sets the column in the data that will be used to determine the height of each bar.
#
# ---

# %% [markdown]
# ## 5 · Heatmap
#
# I have one more plot type to learn about: **Heatmaps**!
#
# Lets drow it...

# %%
# heat map :
plt.figure(figsize=(14, 7))
plt.title('Average Arrival Delay for Each Airline, by Month')

sns.heatmap(data=flight, annot=True)

plt.xlabel('Airline')
# Out:
# Text(0.5, 47.7222222222222, 'Airline')

# %% [markdown]
# This code has three main components:
#
# - `sns.heatmap` - This tells the notebook that we want to create a heatmap.
# - `data=flight` - This tells the notebook to use all of the entries in flight_data to create the heatmap.
# - `annot=True` - This ensures that the values for each cell appear on the chart.

# %% [markdown]
# ---
# ## 6 · Scatter Plot
#
# Now I will work with a (synthetic) dataset of insurance charges.

# %%
# load dataset :
insurance = pd.read_csv('/kaggle/input/datasets/alexisbcook/data-for-datavis/insurance.csv')

# show dataset :
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ---
# Now I will see the relation of body mass index (BMI) with insurance charges by a **Scatter Plot**.

# %%
# scatter Plot :
plt.figure(figsize=(14,7))
plt.title('BMI VS Charge')
sns.scatterplot(x=insurance.bmi, y=insurance.charges)
# Out:
# <Axes: title={'center': 'BMI VS Charge'}, xlabel='bmi', ylabel='charges'>

# %% [markdown]
# The scatterplot above suggests that 'body mass index' (BMI) and insurance charges are positively correlated, where customers with higher BMI typically also tend to pay more in insurance costs.
#
# To double-check the strength of this relationship, you might like to add a regression line, or the line that best fits the data. We do this by changing the command to `sns.regplot`.

# %%
# regrassion plot :
plt.figure(figsize=(14,7))
plt.title('BMI VS Charge')
sns.regplot(x=insurance.bmi, y=insurance.charges)
plt.xlabel('BMI')
plt.ylabel('Charge')
# Out:
# Text(0, 0.5, 'Charge')

# %% [markdown]
# ---
# I can use scatter plots to display the relationships between (not two, but...) three variables! One way of doing this is by color-coding the points. Its called `Color-Coded scatter plot`.
#
# For instance, to understand how smoking affects the relationship between BMI and insurance costs, we can color-code the points by 'smoker', and plot the other two columns ('bmi', 'charges') on the axes.

# %%
# color coded scatter plot :
plt.figure(figsize=(14,7))
plt.title('BMI VS Charge')
sns.scatterplot(x=insurance.bmi, y=insurance.charges, hue=insurance.smoker)
plt.xlabel('BMI')
plt.ylabel('Charge')
# Out:
# Text(0, 0.5, 'Charge')

# %% [markdown]
# This scatter plot shows that while nonsmokers to tend to pay slightly more with increasing BMI, smokers pay MUCH more.
#
# ---
# To further emphasize this fact, we can use the `sns.lmplot()` command to add two regression lines, corresponding to smokers and nonsmokers. (The regression line for smokers has a much steeper slope, relative to the line for nonsmokers!)

# %%
# lm plot :
sns.lmplot(data=insurance, x='bmi', y='charges', hue='smoker')

# %% [markdown]
# The `sns.lmplot` command above works slightly differently than the commands you have learned about so far:
#
# - Instead of setting `x=insurance['bmi']` to select the 'bmi' column in insurance_data, we set `x="bmi"` to specify the name of the column only.
# - Similarly, `y="charges"` and `hue="smoker"` also contain the names of columns.
# - We specify the dataset with `data=insurance`.

# %% [markdown]
# ----
# Finally, there's one more plot that I will learn about.
#
# Usually, we use scatter plots to highlight the relationship between two continuous variables (like "bmi" and "charges"). However, we can adapt the design of the scatter plot to feature a categorical variable (like "smoker") on one of the main axes.
#
# We'll refer to this plot type as a categorical scatter plot, and we build it with the `sns.swarmplot()` command.

# %%
sns.swarmplot(x=insurance['smoker'], y=insurance['charges'])
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='smoker', ylabel='charges'>
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 60.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Among other things, this plot shows us that:
#
# - on average, non-smokers are charged less than smokers, and
# - the customers who pay the most are smokers; whereas the customers who pay the least are non-smokers.

# %% [markdown]
# ---
# ## 7 · Histogram
#
# Now I will work with a dataset of 150 different flowers, or 50 each from three different species of Iris (Iris setosa, Iris versicolor, and Iris virginica). Then I used it to make a **Histogram**. **Histogram** shows us **Distribution** of Data.

# %%
# loading Iris Datasets :
iris = pd.read_csv('/kaggle/input/datasets/alexisbcook/data-for-datavis/iris.csv', index_col='Id')

# Dataset :
iris
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                  5.1               3.5                1.4               0.2
# 2                  4.9               3.0                1.4               0.2
# 3                  4.7               3.2                1.3               0.2
# 4                  4.6               3.1                1.5               0.2
# 5                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 146                6.7               3.0                5.2               2.3
# 147                6.3               2.5                5.0               1.9
# 148                6.5               3.0                5.2               2.0
# 149                6.2               3.4                5.4               2.3
# 150                5.9               3.0                5.1               1.8
#
#             Species
# Id
# ...

# %% [markdown]
# Each row in the dataset corresponds to a different flower. There are four measurements: the sepal length and width, along with the petal length and width. We also keep track of the corresponding species.

# %% [markdown]
# ---
# Now I will create a histogram to see how "Petal Length" varies in iris flowers. I can do this with the `sns.histplot` command.

# %%
# histogram :
sns.histplot(iris['Petal Length (cm)'])
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Count'>

# %% [markdown]
# ---
# We can create three different histograms (one for each species) of petal length by using the `sns.histplot` command .
#
# - `data=` provides the name of the variable that we used to read in the data
# - `x= sets` the name of column with the data we want to plot
# - `hue=` sets the column we'll use to split the data into different histograms

# %%
# Histograms for each species
sns.histplot(data=iris, x='Petal Length (cm)', hue='Species')

# Add title
plt.title("Histogram of Petal Lengths, by Species")
# Out:
# Text(0.5, 1.0, 'Histogram of Petal Lengths, by Species')

# %% [markdown]
# ---
# ## 8 · KDE Plot
#
# The next type of plot is a **Kernel Density Estimate** (KDE) plot. The KDE plots, It can be imagined as a smoothed histogram. **KDE Plot** is a kind of Density Plot.
#
# To make a **KDE** plot, we use the `sns.kdeplot` command. Setting `fill=True` colors the area below the curve (and `data=` chooses the column we would like to plot).

# %%
sns.kdeplot(data=iris['Petal Length (cm)'], fill=True)
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Density'>

# %% [markdown]
# ---
# We can also create a KDE plot for each species by using `sns.kdeplot`. The functionality for `data`, `x`, and `hue` are identical to when we used `sns.histplot` above. Additionally, we set `fill=True` to color the area below each curve.

# %%
# KDE plots for each species
sns.kdeplot(data=iris, x='Petal Length (cm)', hue='Species', fill=True)

# Add title
plt.title("Distribution of Petal Lengths, by Species")
# Out:
# Text(0.5, 1.0, 'Distribution of Petal Lengths, by Species')

# %% [markdown]
# One interesting pattern that can be seen in plots is that the plants seem to belong to one of two groups, where **Iris versicolor** and **Iris virginica** seem to have similar values for *petal length* , while **Iris setosa** belongs in a category all by itself.
#
# In fact, according to this dataset, we might even be able to classify any **iris** plant as **Iris setosa** (as opposed to **Iris versicolor** or **Iris virginica**) just by looking at the petal length: if the petal length of an *iris*  flower is less than 2 cm, it's most likely to be Iris setosa!

# %% [markdown]
# ---
# ## 9 · 2D KDE plots
#
# We're not restricted to a single column when creating a KDE plot. We can create a **Two-Dimensional (2D)** KDE plot with the `sns.jointplot` command.
#
# In the plot below, the color-coding shows us how likely we are to see different combinations of sepal width and petal length, where darker parts of the figure are more likely.

# %%
# 2D KDE plot
sns.jointplot(x=iris['Petal Length (cm)'], y=iris['Sepal Width (cm)'], kind="kde")

# %% [markdown]
# Note that in addition to the 2D KDE plot in the center,
# - the curve at the top of the figure is a KDE plot for the data on the x-axis (in this case, iris `['Petal Length (cm)']`),
# - the curve on the right of the figure is a KDE plot for the data on the y-axis (in this case, iris `['Sepal Width (cm)']`).

# %% [markdown]
# ---
# # Conclusion
#
# I have learned how to create many different chart types. Now, I will organize my knowledge.
#
# Since it's not always easy to decide how to best tell the story behind any data, we have broken the chart types into **Three Broad Categories** to help with this :
#
# - **Trends** - A trend is defined as a pattern of change.
#
#   - `sns.lineplot` - **Line charts** are best to show trends over a period of time, and multiple lines can be used to show trends in more than one group.
#
# ---
# - **Relationship** - There are many different chart types that we can use to understand relationships between variables in data.
#
#   * `sns.barplot` - **Bar charts** are useful for comparing quantities corresponding to different groups.
#
#   * `sns.heatmap` - **Heatmaps** can be used to find color-coded patterns in tables of numbers.
#
#   * `sns.scatterplot` - **Scatter plots** show the relationship between two continuous variables; if **color-coded**, we can also show the relationship with a third categorical variable.
#
#   * `sns.regplot` - Including a **regression line** in the scatter plot makes it easier to see any linear relationship between two variables.
#
#   * `sns.lmplot` - This command is useful for drawing **multiple regression lines**, if the scatter plot contains multiple, color-coded groups.
#
#   * `sns.swarmplot` - **Categorical scatter plots** show the relationship between a continuous variable and a categorical variable.
#
#
# ---
# - **Distribution** - We visualize distributions to show the possible values that we can expect to see in a variable, along with how likely they are.
#
#
#   - `sns.histplot` - **Histograms** show the distribution of a single numerical variable.
#
#   - `sns.kdeplot` - **KDE plots** (or **2D KDE plots**) show an estimated, smooth distribution of a single numerical variable (or two numerical variables).
#
#   - `sns.jointplot` - This command is useful for simultaneously displaying a **2D KDE plot** with the corresponding KDE plots for each individual variable.
#
# ---
